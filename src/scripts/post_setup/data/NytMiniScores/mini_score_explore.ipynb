# %%
import pandas as pd
import collections
import seaborn as sns

# %%
scores = pd.read_csv('mini_scores_wide.csv')
scores.head()
# good for looking at data by date... otherwise use long data
# Out:
#                  date  gnome  andyvo  speckled mug  jack-o-pie  megh
# 0  September 26, 2022     52    70.0          97.0         NaN   NaN
# 1  September 27, 2022     37    61.0          36.0         NaN   NaN
# 2  September 28, 2022     40    56.0          32.0         NaN   NaN
# 3  September 29, 2022     67    68.0          87.0         NaN   NaN
# 4     October 1, 2022    507   253.0         211.0         NaN   NaN

# %%
scores_l = pd.read_csv('mini_scores_long.csv')
scores_l.head()
# Out:
#                  date   user   time
# 0  September 26, 2022  gnome   52.0
# 1  September 27, 2022  gnome   37.0
# 2  September 28, 2022  gnome   40.0
# 3  September 29, 2022  gnome   67.0
# 4     October 1, 2022  gnome  507.0

# %%
# add day of week

# less than 60sec, 40sec, 30sec

# diff from average?...std dev...

# %%
# frequency of completion
(~scores.isna()).sum()
# Out:
# date            160
# gnome           160
# andyvo          113
# speckled mug    108
# jack-o-pie       94
# megh             14
# dtype: int64

# %% [markdown]
# #### over time ideas:
#  - frequency over time
#  - streaks over time
#  - completion time over time

# %%
g = sns.FacetGrid(scores_l, col='user')
g.map(sns.lineplot, 'date', 'time')

# %% [markdown]
# #### cumulative ideas:
# - total time for each user...
# - std dev/variance...
# - average time by user, by date

# %% [markdown]
# #### bonus
# - are weekends actually harder?
